# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 55.3 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train \
model=yolo11n.pt \
data=/content/drive/MyDrive/sollar/sollar.yaml \
epochs=50 \
imgsz=640 \
project=/content/drive/MyDrive/yolo_runs \
name=sollar_yolo11
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# !yolo task=detect mode=predict \
model=/content/drive/MyDrive/yolo_runs/sollar_yolo11/weights/best.pt \
source=/content/drive/MyDrive/sollar/images/val \
conf=0.01 \
iou=0.3 \
save=True
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLO11n summary (fused): 101 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/19 /content/drive/MyDrive/sollar/images/val/Bird (15).JPG: 512x640 4 bird_drops, 208.8ms
# image 2/19 /content/drive/MyDrive/sollar/images/val/Bird (16).JPG: 640x640 4 bird_drops, 232.1ms
# image 3/19 /content/drive/MyDrive/sollar/images/val/Bird (17).jpg: 640x480 5 bird_drops, 164.5ms
# image 4/19 /content/drive/MyDrive/sollar/images/val/Bird (18).jpg: 544x640 8 bird_drops, 201.1ms
# image 5/19 /content/drive/MyDrive/sollar/images/val/Bird (19).jpg: 640x480 13 bird_drops, 151.0ms
# image 6/19 /content/drive/MyDrive/sollar/images/val/Electrical (84).jpg: 416x640 3 bird_drops, 155.5ms
# image 7/19 /content/drive/MyDrive/sollar/images/val/Electrical (90).jpg: 640x448 2 bird_drops, 157.2ms
# image 8/19 /content/drive/MyDrive/sollar/images/val/Electrical (92).jpg: 512x640 4 bird_drops, 177.3ms
# ...

# %%
# !yolo task=detect mode=train \
model=/content/drive/MyDrive/yolo_runs/sollar_yolo11/weights/last.pt \
data=/content/drive/MyDrive/sollar/sollar.yaml \
epochs=100 \
resume=True
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# !yolo task=detect mode=train \
model=yolo11n.pt \
data=/content/drive/MyDrive/sollar/sollar.yaml \
epochs=100
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# !yolo task=detect mode=predict \
model=/content/drive/MyDrive/yolo_runs/sollar_yolo11/weights/best.pt \
source=/content/drive/MyDrive/sollar/images/val \
conf=0.01 \
iou=0.3 \
save=True
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLO11n summary (fused): 101 layers, 2,582,737 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/19 /content/drive/MyDrive/sollar/images/val/Bird (15).JPG: 512x640 4 bird_drops, 199.5ms
# image 2/19 /content/drive/MyDrive/sollar/images/val/Bird (16).JPG: 640x640 4 bird_drops, 246.4ms
# image 3/19 /content/drive/MyDrive/sollar/images/val/Bird (17).jpg: 640x480 5 bird_drops, 168.4ms
# image 4/19 /content/drive/MyDrive/sollar/images/val/Bird (18).jpg: 544x640 8 bird_drops, 190.5ms
# image 5/19 /content/drive/MyDrive/sollar/images/val/Bird (19).jpg: 640x480 13 bird_drops, 150.7ms
# image 6/19 /content/drive/MyDrive/sollar/images/val/Electrical (84).jpg: 416x640 3 bird_drops, 144.0ms
# image 7/19 /content/drive/MyDrive/sollar/images/val/Electrical (90).jpg: 640x448 2 bird_drops, 168.0ms
# image 8/19 /content/drive/MyDrive/sollar/images/val/Electrical (92).jpg: 512x640 4 bird_drops, 176.5ms
# ...
